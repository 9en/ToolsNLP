# %%
import analysisNLP
# %matplotlib inline

# %%
data = [i.strip('\n').split('\t') for i in open('../../test/data.tsv')]

# %%
data[:1]
# Out:
# [['http://news.livedoor.com/article/detail/4778030/',
# ...

# %%
t = analysisNLP.TopicModelWrapper(data=data, config_mw={'dicttype':'neologd'})

# %%
t.get_topic2doccnt_plot()

# %%
t.get_topic2term_plot()

# %%
t.get_topic2topdoc_list()
# Out:
#       topic                                               url    weight
# 711      41  http://news.livedoor.com/article/detail/6435886/  0.967008
# 1863     41  http://news.livedoor.com/article/detail/5965457/  0.951323
# 1692     41  http://news.livedoor.com/article/detail/6910399/  0.910917
# 1855     41  http://news.livedoor.com/article/detail/5961830/  0.876613
# 765      41  http://news.livedoor.com/article/detail/6556566/  0.864925
# 1485     41  http://news.livedoor.com/article/detail/6751343/  0.844212
# 8        41  http://news.livedoor.com/article/detail/4791665/  0.803243
# 1857     41  http://news.livedoor.com/article/detail/5962823/  0.796635
# 1557     41  http://news.livedoor.com/article/detail/6805568/  0.793803
# 1838     41  http://news.livedoor.com/article/detail/5937607/  0.784691
# 841      75  http://news.livedoor.com/article/detail/6771702/  0.974424
# 381      75  http://news.livedoor.com/article/detail/5719298/  0.968037
# ...
